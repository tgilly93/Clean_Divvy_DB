# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv('/Users/terrygilmore/Desktop/Divvy_DB/Divvy_Stations_Trips_2013/Divvy_Trips_2013.csv', low_memory=False)

# %%
df2 = pd.read_csv('/Users/terrygilmore/Desktop/Divvy_DB/Divvy_Stations_Trips_2013/Divvy_Stations_2013.csv')

# %%
df_2013 = pd.concat([df1, df2], axis=1)

# %%
print(df_2013.head())
# Out:
#    trip_id         starttime          stoptime  bikeid  tripduration  \
# 0     4118  2013-06-27 12:11  2013-06-27 12:16     480           316
# 1     4275  2013-06-27 14:44  2013-06-27 14:45      77            64
# 2     4291  2013-06-27 14:58  2013-06-27 15:05      77           433
# 3     4316  2013-06-27 15:06  2013-06-27 15:09      77           123
# 4     4342  2013-06-27 15:13  2013-06-27 15:27      77           852
#
#    from_station_id           from_station_name  to_station_id  \
# 0               85       Michigan Ave & Oak St             28
# 1               32  Racine Ave & Congress Pkwy             32
# 2               32  Racine Ave & Congress Pkwy             19
# 3               19       Loomis St & Taylor St             19
# 4               19       Loomis St & Taylor St             55
#
#                     to_station_name  usertype gender  birthday    id  \
# 0        Larrabee St & Menomonee St  Customer    NaN       NaN   5.0
# 1        Racine Ave & Congress Pkwy  Customer    NaN       NaN  13.0
# 2             Loomis St & Taylor St  Customer    NaN       NaN  14.0
# 3             Loomis St & Taylor St  Customer    NaN       NaN  15.0
# 4  Halsted St & James M Rochford St  Customer    NaN       NaN  16.0
#
#                          name   latitude  longitude  dpcapacity  landmark  \
# 0      State St & Harrison St  41.873958 -87.627739        19.0      30.0
# 1  Wilton Ave & Diversey Pkwy  41.932500 -87.652681        19.0      66.0
# 2         Morgan St & 18th St  41.858086 -87.651073        15.0     163.0
# 3        Racine Ave & 18th St  41.858181 -87.656487        15.0     164.0
# 4         Wood St & North Ave  41.910329 -87.672516        15.0     223.0
#
#   online date
# 0   6/28/2013
# 1   6/28/2013
# 2   6/28/2013
# 3   6/28/2013
# 4   8/12/2013

# %%
df_2013.drop(['gender', 'birthday'], axis=1)
# Out:
#         trip_id         starttime          stoptime  bikeid  tripduration  \
# 0          4118  2013-06-27 12:11  2013-06-27 12:16     480           316
# 1          4275  2013-06-27 14:44  2013-06-27 14:45      77            64
# 2          4291  2013-06-27 14:58  2013-06-27 15:05      77           433
# 3          4316  2013-06-27 15:06  2013-06-27 15:09      77           123
# 4          4342  2013-06-27 15:13  2013-06-27 15:27      77           852
# ...         ...               ...               ...     ...           ...
# 759783  1109257  2013-12-31 21:12  2013-12-31 21:16    1917           284
# 759784  1109276  2013-12-31 21:36  2013-12-31 22:01    2859          1493
# 759785  1109283  2013-12-31 22:03  2013-12-31 22:13     198           650
# 759786  1109309  2013-12-31 22:10  2013-12-31 22:16    2048           346
# 759787  1109338  2013-12-31 22:35  2013-12-31 22:49    2239           868
#
#         from_station_id             from_station_name  to_station_id  \
# 0                    85         Michigan Ave & Oak St             28
# 1                    32    Racine Ave & Congress Pkwy             32
# 2                    32    Racine Ave & Congress Pkwy             19
# 3                    19         Loomis St & Taylor St             19
# 4                    19         Loomis St & Taylor St             55
# ...                 ...                           ...            ...
# 759783               20  Sheffield Ave & Kingsbury St             93
# 759784              227  Southport Ave & Waveland Ave            228
# 759785              284   Michigan Ave & Jackson Blvd             43
# 759786              130       Damen Ave & Division St             69
# 759787              216  California Ave & Division St             69
#
#                          to_station_name    usertype    id  \
# 0             Larrabee St & Menomonee St    Customer   5.0
# 1             Racine Ave & Congress Pkwy    Customer  13.0
# 2                  Loomis St & Taylor St    Customer  14.0
# 3                  Loomis St & Taylor St    Customer  15.0
# 4       Halsted St & James M Rochford St    Customer  16.0
# ...                                  ...         ...   ...
# 759783         Sheffield Ave & Willow St  Subscriber   NaN
# 759784           Damen Ave & Melrose Ave  Subscriber   NaN
# 759785      Michigan Ave & Washington St  Subscriber   NaN
# 759786            Damen Ave & Pierce Ave  Subscriber   NaN
# 759787            Damen Ave & Pierce Ave  Subscriber   NaN
#
#                               name   latitude  longitude  dpcapacity  \
# 0           State St & Harrison St  41.873958 -87.627739        19.0
# 1       Wilton Ave & Diversey Pkwy  41.932500 -87.652681        19.0
# 2              Morgan St & 18th St  41.858086 -87.651073        15.0
# 3             Racine Ave & 18th St  41.858181 -87.656487        15.0
# 4              Wood St & North Ave  41.910329 -87.672516        15.0
# ...                            ...        ...        ...         ...
# 759783                         NaN        NaN        NaN         NaN
# 759784                         NaN        NaN        NaN         NaN
# 759785                         NaN        NaN        NaN         NaN
# 759786                         NaN        NaN        NaN         NaN
# 759787                         NaN        NaN        NaN         NaN
#
#         landmark online date
# 0           30.0   6/28/2013
# 1           66.0   6/28/2013
# 2          163.0   6/28/2013
# 3          164.0   6/28/2013
# 4          223.0   8/12/2013
# ...          ...         ...
# 759783       NaN         NaN
# 759784       NaN         NaN
# 759785       NaN         NaN
# 759786       NaN         NaN
# 759787       NaN         NaN
#
# [759788 rows x 17 columns]
